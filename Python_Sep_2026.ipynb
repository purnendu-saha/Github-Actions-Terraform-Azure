# %% [markdown]
# <a href="https://colab.research.google.com/github/purnendu-saha/Github-Actions-Terraform-Azure/blob/main/Python_Sep_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
X=10
Y=2.3
print(type(X))
print(type(Y))
# Out:
# <class 'int'>
# <class 'float'>

# %%
#
item1=100
item2=300
item3=500
item4=600
deliverycharge=0
charity=1000
tip=500
distance=3
discountpercent=0
loyaltypoint=100
earntpoint=0

sum=item1+item2+item3+item4

if sum>1000:
  discountpercent=10
else:
  discountpercent=5

discountamount=sum*discountpercent/100
sum=sum-discountamount

if distance>5:
    deliverycharge=100
else:
    deliverycharge=50

finalamount=sum+deliverycharge
tax=finalamount*10/100
totalamount=finalamount+tax+charity
totalamountafteraddingtip=totalamount+tip-loyaltypoint

if totalamountafteraddingtip>500:
   earntpoint=totalamountafteraddingtip*2/100
else:
   earntpoint=totalamountafteraddingtip*2/100

print(tax)
print(finalamount)
print(finalamount+tax)
print(totalamount)
print(totalamountafteraddingtip)
print(earntpoint)
# Out:
# 140.0
# 1400.0
# 1540.0
# 2540.0
# 2940.0
# 58.8

# %%
# you are a developer at book my show .com and you've to develop an application that calculate the ticket cost.
# here are to rules to calculate the total price
# ticket price equal or above 18 years 200 INR
#ticket price below above 12 years and below 18 yers 100 INR
#Ticket price below or equal 12 yers 50 INR
#Fimily of 30years father,28years monther,15yesrs one kid, 10 years another kid
#calculate the total cost

husbandage=30
wifeage=28
kid1age=15
kid2age=10

ticketcost=0

if husbandage>=18:
  ticketcost=ticketcost+200
if husbandage>12 and husbandage<18:
  ticketcost=ticketcost+100
if husbandage<=12:
  ticketcost= ticketcost+50

if wifeage>=18:
  ticketcost=ticketcost+200
if wifeage>12 and wifeage<18:
  ticketcost=ticketcost+100
if wifeage<=12:
  ticketcost= ticketcost+50

if kid1age>=18:
  ticketcost=ticketcost+200
if kid1age>12 and kid1age<18:
  ticketcost=ticketcost+100
if kid1age<=12:
  ticketcost= ticketcost+50

if kid2age>=18:
  ticketcost=ticketcost+200
if kid2age>12 and kid1age<18:
  ticketcost=ticketcost+100
if kid2age<=12:
  ticketcost= ticketcost+50

print(ticketcost)
# Out:
# 550

# %%
#you are a developer into cricinfo.com. you have to show prediction
#prediction rules are below
#check the total runs to chase if it is less than total ball left
#chance of chassing team to win is high otherwise less

#Assume IND vs SOUthAfrica match going on
#SA score 200 runs
#IND has already score 90 runs and 60 balls remains
#Tell me the chance of india to win this match

southafricascore=200
totalballremaining=60
indianscore=90

indiascoreremaining= southafricascore-indianscore

if indiascoreremaining<=totalballremaining:
  print("India will win")
else:
  print("India will loss")
# Out:
# India will loss

# %%
#imagine that you got a offer from tcs
# offer details as follows
#if you are having total exp more than 5 years then you will get extra bonua 100000
#imagine your total exp 10 yrs 20% flat tax, if below then 10%
#if your tech is ai you get extrabenefit of 2laks
#you get basic salary,DA equals to 20% of basic salary,hra equals to 40% of basic salary
#assume that you got a offer of 10 Laks rs as basic salary
#tell me your total ctc

Basiscsalary=1000000
DA=Basiscsalary*20/100
HRA=Basiscsalary*40/100
jobexp=10
bonus=0
tax=0
salaryaftertax=0

if jobexp>5:
 bonus=bonus+100000

CTC=Basiscsalary+DA+HRA+bonus
if CTC>1000000:
  tax=CTC*20/100
else:
  tax=CTC*10/100

print("total salary:",CTC)
print("total salary after tax:",CTC-tax)
# Out:
# total salary: 1700000.0
# total salary after tax: 1360000.0

# %%
i=0
while i<5:
  print("hello")
  i=i+1
print("thank you")
# Out:
# hello
# hello
# hello
# hello
# hello
# thank you

# %%
num1=int(input("Enter the Marks"))
num2=int(input("Enter the Marks"))
num3=int(input("Enter the Marks"))
num4=int(input("Enter the Marks"))
num5=int(input("Enter the Marks"))

percentage=(num1+num2+num3+num4+num5)/500*100
print(percentage)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3278/2277720272.py in <cell line: 0>()
# ----> 1 num1=int(input("Enter the Marks"))
#       2 num2=int(input("Enter the Marks"))
#       3 num3=int(input("Enter the Marks"))
#       4 num4=int(input("Enter the Marks"))
#       5 num5=int(input("Enter the Marks"))
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
i=0
sum=0
while i<5:
  num1=int(input("Enter the Marks: "))
  sum=sum+num1
  i=i+1
percentage=(sum*100)/500
print(percentage)
# Out:
# Enter the Marks34
# Enter the Marks78
# Enter the Marks65
# Enter the Marks56
# Enter the Marks89
# 64.4

# %%
#you are building ctc calculator
#use to enter basic,da,hra
#reocation allowances
#you need to calculate total ctc

basic=int(input("Enter the basic: "))
hra=int(input("Enter the hra: "))
da=int(input("Enter the da: "))
onetimebonus=int(input("Enter the onetimebonus: "))
ra=int(input("Enter the ra: "))

ctc=(basic+hra+da+onetimebonus+ra)
print(ctc)
# Out:
# Enter the basic4000
# Enter the hra450
# Enter the da3456
# Enter the onetimebonus678
# Enter the ra76
# 8660

# %%
#user has been ask to enter the 5 nos
#for every positive no he'll get 100 points
#for every negative no there is no point
#have to tell at the end tell me the total points

#assume 2,10,-10,-20,30
#output: 300

i = 0
point = 0
while i < 5:
    num1 = int(input("Enter the number: "))
    if num1 > 0:
        point = point + 100
    i = i + 1

print("Total points:", point)
# Out:
# Enter the number: -30
# Enter the number: 10
# Enter the number: -90
# Enter the number: 20
# Enter the number: -10
# Total points: 200

# %%
#user has been ask to enter the 5 nos
#for every positive no he'll get 100 points
#for every negative no there is panalty of 100 points
#have to tell at the end tell me the total points

#assume 2,10,-10,-20,30
#output: 300

i = 0
point = 0
while i < 5:
    num1 = int(input("Enter the number: "))
    if num1 > 0:
        point = point + 100
    else:
      point = point - 100
    i = i + 1

print("Total points:", point)
# Out:
# Enter the number: 90
# Enter the number: -20
# Enter the number: 8
# Enter the number: -40
# Enter the number: 78
# Total points: 100

# %%
#Question 1: A store sells apples at $5 each and bananas at $3 each.
#Declare variables apples_price and bananas_price with appropriate values.
#Calculate the total cost for purchasing 10 apples and 7 bananas and store the result in total_cost.

apples_price=5
bananas_price=3

total_cost= (apples_price*10)+(bananas_price*10)
print("Total cost of 10 apples and 7 bananas is: ",total_cost)
# Out:
# Total cost of 10 apples and 7 bananas is:  80

# %%
#Question 2: You have a monthly salary of $4,000 and
#expenses that include rent ($1,200), groceries ($300), and miscellaneous ($500).
#Calculate the amount left after expenses and store it in a variable named remaining_balance.

monthly_salary=4000
rent=1200
groceries=300
miscellaneous=500
expense=rent+groceries+miscellaneous

remaining_balance= monthly_salary-expense

print("Monthly remaining balance after expenses: ",remaining_balance)
# Out:
# Monthly remaining balance after expenses:  2000

# %%
#Question 3: A team won 28 matches this season, and last season they won 18 matches.
# Declare variables current_season_wins and last_season_wins with respective values.
#Calculate the increase in matches won and store it in win_difference.

# %%
#Question 4: A travel company charges $250 per person for a weekend trip and gives a $100 group discount for every 5 people.
#If a group has 15 people Calculate the total cost for the group and store it in group_trip_cost.

# %%
#Question 5: An item costs $120, and there is a discount of 15%.
#Calculate the final price after the discount and store it in discounted_price.

# %%
#Question 6: A company produces 500 units daily and sells each unit for $20.
#Declare variables units_per_day and price_per_unit.
#Calculate the monthly revenue assuming a 30-day month and store it in monthly_revenue.

# %%
#Question 7: A farmer grows wheat on a 150-acre farm and yields 3,000 kg per acre.
#Declare variables acreage and yield_per_acre.
#Calculate the total wheat production and store it in total_production.

# %%
#Question 8: A bakery makes $2 profit on each loaf of bread sold.
#If they sell 200 loaves in a day, declare variables profit_per_loaf and loaves_sold.
#Calculate the daily profit and store it in daily_profit.

# %%
#Question 9: You are planning an event for 120 attendees.
#The venue rental is $800, and catering costs $25 per person.
#Declare variables venue_cost, catering_cost_per_person, and number_of_attendees.
#Calculate the total cost of the event and store it in event_total_cost.

# %%
#Question 10: A school's annual fee per student is $1,500, and they provide a 5% sibling discount.
#Declare variables annual_fee and sibling_discount_percent.
#Calculate the discounted fee for one sibling and store it in sibling_discounted_fee.

# %%
# 04th September 2026

# %%
items=['milk','bread','butter']
print(items)
print(items[0])
print(items[1])
print(items[2])
print(len(items))
# Out:
# ['milk', 'bread', 'butter']
# milk
# bread
# butter
# 3

# %%
items.append('fruits')
print(items)
# Out:
# ['milk', 'bread', 'butter', 'fruits']

# %%
items.insert(1,'icecream')
print(items)
# Out:
# ['milk', 'icecream', 'bread', 'butter', 'fruits']

# %%
item=items.pop()
print(item)
print(items)
# Out:
# fruits
# ['milk', 'icecream', 'bread', 'butter']

# %%
item=items.pop(1)
print(item)
print(items)
# Out:
# icecream
# ['milk', 'bread', 'butter']

# %%
items[1]='wheat bread'
print(items)
# Out:
# ['milk', 'wheat bread', 'butter']

# %%
print(items)
# Out:
# ['milk', 'wheat bread', 'butter']

# %%
i=0
while i<len(items):
  print(items[i])
  i=i+1
# Out:
# milk
# wheat bread
# butter

# %%
#for loop
for var_name in items:
   print(var_name)
# Out:
# milk
# wheat bread
# butter

# %%
#imagine that you are working as a developer in blink it
#user is going to add multiple items in there carts
#your work is to ask the user the items he wants to add
#later on for the confirmation you need to display
#all the items with there counts
#user will enter 5 fixed items

i=0
items=[]
while i<5:
  item=input("Enter the item name: ")
  items.append(item)
  i=i+1

for i in items:
  print(i)

#for i in range(5):
# Out:
# Enter the item name: apple
# Enter the item name: orange
# Enter the item name: banana
# Enter the item name: coconut
# Enter the item name: jamun
# apple
# orange
# banana
# coconut
# jamun
